# %%
import pandas as pd
airbnb = pd.read_csv("AB_US_2020.csv")
# Out:
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3460: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sampled_airbnb = airbnb.sample(n=500)
exploration = sampled_airbnb[:250]
evaluation = sampled_airbnb[250:]

# %%
exploration
# Out:
#               id                                              name    host_id  \
# 196355  14180539               Spacious Private Bedroom & Skylight     547669
# 188841  27902672              Updated Guest House With City Views!   22012010
# 158787  42405876                     Murray Hill One Bedroom Apt-P  337491638
# 134461  17078010   Bushwick apartment (bedroom) right off L train!    1286399
# 203756  41645656   3BR/3BA, Beach in walking distance, 20min to Sf    2310061
# ...          ...                                               ...        ...
# 98378   40596229  Cozy private room/bath in Los Angeles-Mar Vista!   22386213
# 213278  16295855                   Lovely Home in St Louis Park MN   70136908
# 117693    248717               Brownstone comfort + beautiful yard    1269526
# 139446  21924203                  Private room in Brownstone house   22378099
# 43806   42644068      Cozy private room & bath: close to downtown!  185084886
#
# ...

# %%
exploration.to_csv('airbnb_exploration.csv')

# %%
evaluation
# Out:
#               id                                               name  \
# 196525  15377291               Trendy Corona Heights Bi-level Condo
# 168889  28226239                         mid-century Garden Cottage
# 163442   6973983                 3 BR, 2 bath, Spacious & beautiful
# 198132  26668091                   SOMA 1 Bedroom Near near Lyft HQ
# 35805   20364136  Merlot remodeled close to airport , Strip and ...
# ...          ...                                                ...
# 56592   20906102                                   Hilo Bay Sunrise
# 57078   21568099            2BR/1BA Condo. Free PARKING, Free WiFi!
# 161077  43857333            Warm and Cozy 2BR in Financial District
# 60081   27575087                       Seashells in Paradise Studio
# 56488   20741902  Sunny Beach Villa! Free Wifi, Parking, Ocean, ...
#
#           host_id           host_name neighbourhood_group  \
# 196525    1479964               James                 NaN
# ...

# %%
evaluation.to_csv('airbnb_evaluation.csv')
